# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\mk744\Downloads\May'24.csv")

# %%
df.head()
# Out:
#                      Program  Clicks  Leads   Sale Amount        Payout  \
# 0  Walmart Affiliate Program    2409    262  1.368174e+08  4.211387e+05
# 1                    NordVPN     365     19  6.347903e+06  2.539217e+06
# 2                     DHgate     378     17  3.234966e+06  2.251740e+05
# 3                    InVideo      62      3  0.000000e+00  0.000000e+00
# 4       Wondershare Software     311      2  2.851493e+05  8.560053e+04
#
#        CR    Date
# 0  0.1088  May'24
# 1  0.0521  May'24
# 2  0.0450  May'24
# 3  0.0484  May'24
# 4  0.0064  May'24

# %%
# convert scientific value into numeric values
if 'Sale Amount' in df.columns and 'Payout' in df.columns:
    df[['Sale Amount', 'Payout']] = df[['Sale Amount', 'Payout']].astype('float')
    df[['Sale Amount', 'Payout']] = df[['Sale Amount', 'Payout']].applymap(lambda x: '{:.0f}'.format(x))
    df[['Sale Amount', 'Payout']] = df[['Sale Amount', 'Payout']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#                      Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0  Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                    NordVPN     365     19      6347903  2539217  0.0521
# 2                     DHgate     378     17      3234966   225174  0.0450
# 3                    InVideo      62      3            0        0  0.0484
# 4       Wondershare Software     311      2       285149    85601  0.0064
#
#      Date
# 0  May'24
# 1  May'24
# 2  May'24
# 3  May'24
# 4  May'24

# %%
# Check and filter rows where specific columns are not NaN
columns_to_check = ['Program', 'Clicks', 'Sale Amount', 'Payout']
mask = df[columns_to_check].notna().all(axis=1)
df_filtered = df[mask]

print("Filtered DataFrame:")
df_filtered.head()
# Out:
# Filtered DataFrame:
#                      Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0  Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                    NordVPN     365     19      6347903  2539217  0.0521
# 2                     DHgate     378     17      3234966   225174  0.0450
# 3                    InVideo      62      3            0        0  0.0484
# 4       Wondershare Software     311      2       285149    85601  0.0064
#
#      Date
# 0  May'24
# 1  May'24
# 2  May'24
# 3  May'24
# 4  May'24

# %%
df.iloc[0:14, 0:7]
# Out:
#                       Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0   Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                     NordVPN     365     19      6347903  2539217  0.0521
# 2                      DHgate     378     17      3234966   225174  0.0450
# 3                     InVideo      62      3            0        0  0.0484
# 4        Wondershare Software     311      2       285149    85601  0.0064
# 5                DigitalOcean     229      2            0        0  0.0087
# 6                   Namecheap     173      2        12688     4604  0.0116
# 7                    Blinkist      60      2            0        0  0.0333
# 8                    CASETiFY     145      1       431601    43160  0.0069
# 9                        Wish      72      1        96581     2925  0.0139
# 10                     Bubble      41      1            0        0  0.0244
# ...

# %%
df[df['Clicks'] > 100]
# Out:
#                       Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0   Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                     NordVPN     365     19      6347903  2539217  0.0521
# 2                      DHgate     378     17      3234966   225174  0.0450
# 4        Wondershare Software     311      2       285149    85601  0.0064
# 5                DigitalOcean     229      2            0        0  0.0087
# 6                   Namecheap     173      2        12688     4604  0.0116
# 8                    CASETiFY     145      1       431601    43160  0.0069
# 13        OnePlus US & Canada     125      0            0        0  0.0000
# 14                   Banggood     113      0            0        0  0.0000
#
#       Date
# 0   May'24
# 1   May'24
# 2   May'24
# 4   May'24
# 5   May'24
# 6   May'24
# 8   May'24
# 13  May'24
# 14  May'24

# %%
df[df['Payout']>=1000]
# Out:
#                       Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0   Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                     NordVPN     365     19      6347903  2539217  0.0521
# 2                      DHgate     378     17      3234966   225174  0.0450
# 4        Wondershare Software     311      2       285149    85601  0.0064
# 6                   Namecheap     173      2        12688     4604  0.0116
# 8                    CASETiFY     145      1       431601    43160  0.0069
# 9                        Wish      72      1        96581     2925  0.0139
# 11              Lenovo Mexico      15      1      5425716   314690  0.0667
# 12                   SSLs.com       2      1        69564    24372  0.5000
#
#       Date
# 0   May'24
# 1   May'24
# 2   May'24
# 4   May'24
# 6   May'24
# 8   May'24
# 9   May'24
# 11  May'24
# 12  May'24

# %%
df[df['Payout'].isin([2539217, 421139, 225174, 85601])]
# Out:
#                      Program  Clicks  Leads  Sale Amount   Payout      CR  \
# 0  Walmart Affiliate Program    2409    262    136817388   421139  0.1088
# 1                    NordVPN     365     19      6347903  2539217  0.0521
# 2                     DHgate     378     17      3234966   225174  0.0450
# 4       Wondershare Software     311      2       285149    85601  0.0064
#
#      Date
# 0  May'24
# 1  May'24
# 2  May'24
# 4  May'24

# %%
# how to find number of columns
for col in df:
     print(col)
# Out:
# Program
# Clicks
# Leads
# Sale Amount
# Payout
# CR
# Date

# %%
# number of rows
for rows in df.iterrows():
     print(rows)
# Out:
# (0, Program        Walmart Affiliate Program
# Clicks                              2409
# Leads                                262
# Sale Amount                    136817388
# Payout                            421139
# CR                                0.1088
# Date                              May'24
# Name: 0, dtype: object)
# (1, Program        NordVPN
# Clicks             365
# Leads               19
# Sale Amount    6347903
# Payout         2539217
# CR              0.0521
# Date            May'24
# Name: 1, dtype: object)
# (2, Program         DHgate
# Clicks             378
# Leads               17
# Sale Amount    3234966
# Payout          225174
# CR               0.045
# Date            May'24
# Name: 2, dtype: object)
# (3, Program        InVideo
# Clicks              62
# Leads                3
# Sale Amount          0
# Payout               0
# CR              0.0484
# Date            May'24
# Name: 3, dtype: object)
# (4, Program        Wondershare Software
# ...

# %%
for row in df.itertuples():
     print(row)
# Out:
# Pandas(Index=0, Program='Walmart Affiliate Program', Clicks=2409, Leads=262, _4=136817388, Payout=421139, CR=0.1088, Date="May'24")
# Pandas(Index=1, Program='NordVPN', Clicks=365, Leads=19, _4=6347903, Payout=2539217, CR=0.0521, Date="May'24")
# Pandas(Index=2, Program='DHgate', Clicks=378, Leads=17, _4=3234966, Payout=225174, CR=0.045, Date="May'24")
# Pandas(Index=3, Program='InVideo', Clicks=62, Leads=3, _4=0, Payout=0, CR=0.0484, Date="May'24")
# Pandas(Index=4, Program='Wondershare Software', Clicks=311, Leads=2, _4=285149, Payout=85601, CR=0.0064, Date="May'24")
# Pandas(Index=5, Program='DigitalOcean', Clicks=229, Leads=2, _4=0, Payout=0, CR=0.0087, Date="May'24")
# Pandas(Index=6, Program='Namecheap', Clicks=173, Leads=2, _4=12688, Payout=4604, CR=0.0116, Date="May'24")
# Pandas(Index=7, Program='Blinkist', Clicks=60, Leads=2, _4=0, Payout=0, CR=0.0333, Date="May'24")
# ...

# %%
df.groupby(['Program'], as_index= False)['Payout'].sum().sort_values(by = ['Payout',], ascending= False).head()
# Out:
#                       Program   Payout
# 23                    NordVPN  2539217
# 29  Walmart Affiliate Program   421139
# 16              Lenovo Mexico   314690
# 9                      DHgate   225174
# 32       Wondershare Software    85601

# %%
df[['Program', 'Clicks', 'Payout', 'Date']].sort_values(by=['Payout'], ascending= False).head(9)
# Out:
#                       Program  Clicks   Payout    Date
# 1                     NordVPN     365  2539217  May'24
# 0   Walmart Affiliate Program    2409   421139  May'24
# 11              Lenovo Mexico      15   314690  May'24
# 2                      DHgate     378   225174  May'24
# 4        Wondershare Software     311    85601  May'24
# 8                    CASETiFY     145    43160  May'24
# 12                   SSLs.com       2    24372  May'24
# 6                   Namecheap     173     4604  May'24
# 9                        Wish      72     2925  May'24

# %%
df.memory_usage()
# Out:
# Index          128
# Program        264
# Clicks         264
# Leads          264
# Sale Amount    264
# Payout         264
# CR             264
# Date           264
# dtype: int64

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Program      33 non-null     object
#  1   Clicks       33 non-null     int64
#  2   Leads        33 non-null     int64
#  3   Sale Amount  33 non-null     int64
#  4   Payout       33 non-null     int64
#  5   CR           33 non-null     float64
#  6   Date         33 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 5.7 KB

# %%
df.memory_usage().sum()
# Out:
# 1976

# %%
Data = pd.read_csv(r"C:\Users\mk744\Downloads\Power BI project\Shoogloo XO CR Jan-24 to Apr-24.csv")

# %%
pd.set_option('display.max_columns', 20)

# %%
Data.head()
# Out:
#               conversion_id                  click_id  campaign_id  \
# 0  65920089020cfa0516b79494  6591b701c93ae10341d0f461            4
# 1  65920ebd00aa5d04e559bd70  65920579a32e370349dfb922            4
# 2  659271fc971dbd04a5f3d618  659264cc67f02b03465efe14            4
# 3  6592720d5d41f8052403061d  659269027bd03f0345903b6d            4
# 4  6592720d5d41f80524030639  65926924457fed033e5ca8bf            4
#
#   campaign_name conversion_method country        city               isp  \
# 0      Flipkart       acquisition      IN  Bantumilli            Airtel
# 1      Flipkart       acquisition      IN  Gachibowli  Airtel Broadband
# 2      Flipkart       acquisition      IN      Khurda               Jio
# 3      Flipkart       acquisition      IN   Ahmedabad               Jio
# 4      Flipkart       acquisition      IN   Hyderabad            Airtel
#
#   goal_id goal_name  ... payout_in_campaign_currency  payout_in_user_currency  \
# ...

# %%
ans = Data[['conversion_id', 'click_id', 'campaign_name', 'conversion_method', 'country', 'city', 'isp', 'goal_id', 'goal_name','payout_in_campaign_currency', 'payout_in_user_currency', 'sale_amount_in_campaign_currency']][:5]

# %%
ans
# Out:
#               conversion_id                  click_id campaign_name  \
# 0  65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1  65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2  659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3  6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4  6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
#
#   conversion_method country        city               isp goal_id goal_name  \
# 0       acquisition      IN  Bantumilli            Airtel     NaN   Default
# 1       acquisition      IN  Gachibowli  Airtel Broadband     NaN   Default
# 2       acquisition      IN      Khurda               Jio     NaN   Default
# 3       acquisition      IN   Ahmedabad               Jio     NaN   Default
# 4       acquisition      IN   Hyderabad            Airtel     NaN   Default
#
#    payout_in_campaign_currency  payout_in_user_currency  \
# ...

# %%
ans.memory_usage()
# Out:
# Index                               128
# conversion_id                        40
# click_id                             40
# campaign_name                        40
# conversion_method                    40
# country                              40
# city                                 40
# isp                                  40
# goal_id                              40
# goal_name                            40
# payout_in_campaign_currency          40
# payout_in_user_currency              40
# sale_amount_in_campaign_currency     40
# dtype: int64

# %%
ans.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   conversion_id                     5 non-null      object
#  1   click_id                          5 non-null      object
#  2   campaign_name                     5 non-null      object
#  3   conversion_method                 5 non-null      object
#  4   country                           5 non-null      object
#  5   city                              5 non-null      object
#  6   isp                               5 non-null      object
#  7   goal_id                           0 non-null      object
#  8   goal_name                         5 non-null      object
#  9   payout_in_campaign_currency       5 non-null      float64
#  10  payout_in_user_currency           5 non-null      float64
# ...

# %%
ans.memory_usage().sum()
# Out:
# 608

# %%
len(Data)
# Out:
# 2949

# %%
Data.shape
# Out:
# (2949, 119)

# %%
Data.nunique()
# Out:
# conversion_id        2949
# click_id             2379
# campaign_id             6
# campaign_name           6
# conversion_method       3
#                      ...
# created_date          114
# created_time          548
# Inventory               1
# Partner                 1
# Email_id                1
# Length: 119, dtype: int64

# %%
Data['campaign_id'].duplicated().sum()
# Out:
# 2943

# %%
Data['campaign_id'].unique()
# Out:
# array([  4,   8,  46, 277,  48,  68], dtype=int64)

# %%
Data.shape[1]
# Out:
# 119

# %%
Data.groupby(['conversion_id'], as_index= False)['campaign_name'].sum().sort_values(by ="campaign_name", ascending=False).head(1)
# Out:
#                  conversion_id campaign_name
# 2560  661cd5188dc89b4fe424579f     mCaffeine

# %%
Data.columns
# Out:
# Index(['conversion_id', 'click_id', 'campaign_id', 'campaign_name',
#        'conversion_method', 'country', 'city', 'isp', 'goal_id', 'goal_name',
#        ...
#        'payout_in_campaign_currency', 'payout_in_user_currency',
#        'sale_amount_in_campaign_currency', 'sale_amount_in_user_currency',
#        'campaign_currency', 'created_date', 'created_time', 'Inventory',
#        'Partner', 'Email_id'],
#       dtype='object', length=119)

# %%
import warnings
warnings.filterwarnings('ignore')
Data.groupby(by = ['conversion_id']).sum().mean()['payout_in_user_currency']
# Out:
# 20.52826449643947

# %%
Ans = Data[['conversion_id', 'click_id', 'campaign_name', 'conversion_method', 'country', 'city', 'isp', 'goal_id', 'goal_name','payout_in_campaign_currency', 'payout_in_user_currency', 'sale_amount_in_campaign_currency']]

# %%
vec = Ans[['conversion_id', 'click_id', 'city', 'goal_id', 'goal_name', 'isp']]
vec.isnull().head(30)
# Out:
#     conversion_id  click_id   city  goal_id  goal_name    isp
# 0           False     False  False     True      False  False
# 1           False     False  False     True      False  False
# 2           False     False  False     True      False  False
# 3           False     False  False     True      False  False
# 4           False     False  False     True      False  False
# 5           False     False  False     True      False  False
# 6           False     False  False     True      False  False
# 7           False     False  False     True      False  False
# 8           False     False  False     True      False  False
# 9           False     False  False     True      False  False
# 10          False     False  False     True      False  False
# 11          False     False  False     True      False  False
# 12          False     False  False     True      False  False
# 13          False     False  False     True      False  False
# ...

# %%
vec.notnull().head(40)
# Out:
#     conversion_id  click_id  city  goal_id  goal_name   isp
# 0            True      True  True    False       True  True
# 1            True      True  True    False       True  True
# 2            True      True  True    False       True  True
# 3            True      True  True    False       True  True
# 4            True      True  True    False       True  True
# 5            True      True  True    False       True  True
# 6            True      True  True    False       True  True
# 7            True      True  True    False       True  True
# 8            True      True  True    False       True  True
# 9            True      True  True    False       True  True
# 10           True      True  True    False       True  True
# 11           True      True  True    False       True  True
# 12           True      True  True    False       True  True
# 13           True      True  True    False       True  True
# 14           True      True  True    False       True  True
# ...

# %%
vec['goal_id'] = vec['goal_id'].bfill()

# %%
vec
# Out:
#                  conversion_id                  click_id        city  \
# 0     65920089020cfa0516b79494  6591b701c93ae10341d0f461  Bantumilli
# 1     65920ebd00aa5d04e559bd70  65920579a32e370349dfb922  Gachibowli
# 2     659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Khurda
# 3     6592720d5d41f8052403061d  659269027bd03f0345903b6d   Ahmedabad
# 4     6592720d5d41f80524030639  65926924457fed033e5ca8bf   Hyderabad
# ...                        ...                       ...         ...
# 2944  66323ea337ee99325f5ccb71  66323ea337ee99325f5ccb70          XX
# 2945  66323ead37ee99325f5ccc43  66323ead37ee99325f5ccc42          XX
# 2946  66323eb537ee99325f5cccf4  66323eb537ee99325f5cccf3          XX
# 2947  66323ec937ee99325f5ccea7  66323ec937ee99325f5ccea6          XX
# 2948  66323ecb37ee99325f5ccecb  66323ecb37ee99325f5cceca          XX
#
#                        goal_id goal_name               isp
# 0     655c590c7746c16a12150895   Default            Airtel
# ...

# %%
vec['goal_id'].dropna(how='all')
# Out:
# 0       655c590c7746c16a12150895
# 1       655c590c7746c16a12150895
# 2       655c590c7746c16a12150895
# 3       655c590c7746c16a12150895
# 4       655c590c7746c16a12150895
#                   ...
# 2944    655c590c7746c16a12150895
# 2945    655c590c7746c16a12150895
# 2946    655c58e5e2ae6d4a18742d03
# 2947    655c590c7746c16a12150895
# 2948    655c590c7746c16a12150895
# Name: goal_id, Length: 2949, dtype: object

# %%
vec['goal_id']
# Out:
# 0       655c590c7746c16a12150895
# 1       655c590c7746c16a12150895
# 2       655c590c7746c16a12150895
# 3       655c590c7746c16a12150895
# 4       655c590c7746c16a12150895
#                   ...
# 2944    655c590c7746c16a12150895
# 2945    655c590c7746c16a12150895
# 2946    655c58e5e2ae6d4a18742d03
# 2947    655c590c7746c16a12150895
# 2948    655c590c7746c16a12150895
# Name: goal_id, Length: 2949, dtype: object

# %%
vec['goal_id'].fillna(method = "ffill")
# Out:
# 0       655c590c7746c16a12150895
# 1       655c590c7746c16a12150895
# 2       655c590c7746c16a12150895
# 3       655c590c7746c16a12150895
# 4       655c590c7746c16a12150895
#                   ...
# 2944    655c590c7746c16a12150895
# 2945    655c590c7746c16a12150895
# 2946    655c58e5e2ae6d4a18742d03
# 2947    655c590c7746c16a12150895
# 2948    655c590c7746c16a12150895
# Name: goal_id, Length: 2949, dtype: object

# %%
ans
# Out:
#               conversion_id                  click_id campaign_name  \
# 0  65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1  65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2  659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3  6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4  6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
#
#   conversion_method country        city               isp goal_id goal_name  \
# 0       acquisition      IN  Bantumilli            Airtel     NaN   Default
# 1       acquisition      IN  Gachibowli  Airtel Broadband     NaN   Default
# 2       acquisition      IN      Khurda               Jio     NaN   Default
# 3       acquisition      IN   Ahmedabad               Jio     NaN   Default
# 4       acquisition      IN   Hyderabad            Airtel     NaN   Default
#
#    payout_in_campaign_currency  payout_in_user_currency  \
# ...

# %%
ans['goal_id'].fillna(0, inplace=True)

# %%
ans
# Out:
#               conversion_id                  click_id campaign_name  \
# 0  65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1  65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2  659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3  6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4  6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
#
#   conversion_method country        city               isp  goal_id goal_name  \
# 0       acquisition      IN  Bantumilli            Airtel        0   Default
# 1       acquisition      IN  Gachibowli  Airtel Broadband        0   Default
# 2       acquisition      IN      Khurda               Jio        0   Default
# 3       acquisition      IN   Ahmedabad               Jio        0   Default
# 4       acquisition      IN   Hyderabad            Airtel        0   Default
#
#    payout_in_campaign_currency  payout_in_user_currency  \
# ...

# %%
Ans.head()
# Out:
#               conversion_id                  click_id campaign_name  \
# 0  65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1  65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2  659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3  6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4  6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
#
#   conversion_method country        city               isp goal_id goal_name  \
# 0       acquisition      IN  Bantumilli            Airtel     NaN   Default
# 1       acquisition      IN  Gachibowli  Airtel Broadband     NaN   Default
# 2       acquisition      IN      Khurda               Jio     NaN   Default
# 3       acquisition      IN   Ahmedabad               Jio     NaN   Default
# 4       acquisition      IN   Hyderabad            Airtel     NaN   Default
#
#    payout_in_campaign_currency  payout_in_user_currency  \
# ...

# %%
Ans.isnull().sum()
# Out:
# conversion_id                          0
# click_id                               0
# campaign_name                          0
# conversion_method                      0
# country                                0
# city                                   0
# isp                                    0
# goal_id                             2536
# goal_name                              0
# payout_in_campaign_currency            0
# payout_in_user_currency                0
# sale_amount_in_campaign_currency       0
# dtype: int64

# %%
VEC = Ans['goal_id'].fillna("missing",inplace=True)

# %%
Ans
# Out:
#                  conversion_id                  click_id campaign_name  \
# 0     65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1     65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2     659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3     6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4     6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
# ...                        ...                       ...           ...
# 2944  66323ea337ee99325f5ccb71  66323ea337ee99325f5ccb70        Myntra
# 2945  66323ead37ee99325f5ccc43  66323ead37ee99325f5ccc42        Myntra
# 2946  66323eb537ee99325f5cccf4  66323eb537ee99325f5cccf3        Myntra
# 2947  66323ec937ee99325f5ccea7  66323ec937ee99325f5ccea6        Myntra
# 2948  66323ecb37ee99325f5ccecb  66323ecb37ee99325f5cceca        Myntra
#
#      conversion_method country        city               isp  \
# ...

# %%
Ans.drop_duplicates()
# Out:
#                  conversion_id                  click_id campaign_name  \
# 0     65920089020cfa0516b79494  6591b701c93ae10341d0f461      Flipkart
# 1     65920ebd00aa5d04e559bd70  65920579a32e370349dfb922      Flipkart
# 2     659271fc971dbd04a5f3d618  659264cc67f02b03465efe14      Flipkart
# 3     6592720d5d41f8052403061d  659269027bd03f0345903b6d      Flipkart
# 4     6592720d5d41f80524030639  65926924457fed033e5ca8bf      Flipkart
# ...                        ...                       ...           ...
# 2944  66323ea337ee99325f5ccb71  66323ea337ee99325f5ccb70        Myntra
# 2945  66323ead37ee99325f5ccc43  66323ead37ee99325f5ccc42        Myntra
# 2946  66323eb537ee99325f5cccf4  66323eb537ee99325f5cccf3        Myntra
# 2947  66323ec937ee99325f5ccea7  66323ec937ee99325f5ccea6        Myntra
# 2948  66323ecb37ee99325f5ccecb  66323ecb37ee99325f5cceca        Myntra
#
#      conversion_method country        city               isp  \
# ...

# %%
Data.drop_duplicates()
# Out:
#                  conversion_id                  click_id  campaign_id  \
# 0     65920089020cfa0516b79494  6591b701c93ae10341d0f461            4
# 1     65920ebd00aa5d04e559bd70  65920579a32e370349dfb922            4
# 2     659271fc971dbd04a5f3d618  659264cc67f02b03465efe14            4
# 3     6592720d5d41f8052403061d  659269027bd03f0345903b6d            4
# 4     6592720d5d41f80524030639  65926924457fed033e5ca8bf            4
# ...                        ...                       ...          ...
# 2944  66323ea337ee99325f5ccb71  66323ea337ee99325f5ccb70            8
# 2945  66323ead37ee99325f5ccc43  66323ead37ee99325f5ccc42            8
# 2946  66323eb537ee99325f5cccf4  66323eb537ee99325f5cccf3            8
# 2947  66323ec937ee99325f5ccea7  66323ec937ee99325f5ccea6            8
# 2948  66323ecb37ee99325f5ccecb  66323ecb37ee99325f5cceca            8
#
#      campaign_name conversion_method country        city               isp  \
# ...

# %%
demo = Data[['campaign_name', 'country', 'city', 'payout_in_user_currency', 'created_date', 'campaign_currency']]

# %%
demo.head()
# Out:
#   campaign_name country        city  payout_in_user_currency created_date  \
# 0      Flipkart      IN  Bantumilli                     19.8     1/1/2024
# 1      Flipkart      IN  Gachibowli                     12.6     1/1/2024
# 2      Flipkart      IN      Khurda                     13.5     1/1/2024
# 3      Flipkart      IN   Ahmedabad                      3.6     1/1/2024
# 4      Flipkart      IN   Hyderabad                      3.6     1/1/2024
#
#   campaign_currency
# 0               INR
# 1               INR
# 2               INR
# 3               INR
# 4               INR

# %%
demo[:60]
# Out:
#    campaign_name country           city  payout_in_user_currency created_date  \
# 0       Flipkart      IN     Bantumilli                     19.8     1/1/2024
# 1       Flipkart      IN     Gachibowli                     12.6     1/1/2024
# 2       Flipkart      IN         Khurda                     13.5     1/1/2024
# 3       Flipkart      IN      Ahmedabad                      3.6     1/1/2024
# 4       Flipkart      IN      Hyderabad                      3.6     1/1/2024
# 5       Flipkart      IN         Rajkot                      3.6     1/1/2024
# 6       Flipkart      IN         Howrah                      3.6     1/1/2024
# 7       Flipkart      IN      Hyderabad                      3.6     1/1/2024
# 8       Flipkart      IN          Delhi                      4.5     1/1/2024
# 9       Flipkart      IN          Delhi                      4.5     1/1/2024
# 10      Flipkart      IN          Delhi                      4.5     1/1/2024
# ...

# %%
demo.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2944    False
# 2945    False
# 2946    False
# 2947    False
# 2948    False
# Length: 2949, dtype: bool

# %%
# to convert into lower case
lowercase = demo['campaign_name'].str.lower()

# %%
lowercase.head(60)
# Out:
# 0     flipkart
# 1     flipkart
# 2     flipkart
# 3     flipkart
# 4     flipkart
# 5     flipkart
# 6     flipkart
# 7     flipkart
# 8     flipkart
# 9     flipkart
# 10    flipkart
# 11    flipkart
# 12    flipkart
# 13    flipkart
# 14    flipkart
# 15    flipkart
# 16    flipkart
# 17    flipkart
# 18    flipkart
# 19    flipkart
# 20    flipkart
# 21    flipkart
# 22    flipkart
# 23    flipkart
# 24    flipkart
# 25    flipkart
# 26    flipkart
# 27    flipkart
# 28    flipkart
# 29    flipkart
# 30    flipkart
# 31    flipkart
# 32    flipkart
# 33    flipkart
# 34    flipkart
# 35    flipkart
# 36    flipkart
# 37    flipkart
# 38    flipkart
# 39    flipkart
# 40    flipkart
# 41    flipkart
# 42    flipkart
# 43    flipkart
# 44    flipkart
# 45    flipkart
# 46    flipkart
# 47    flipkart
# 48    flipkart
# 49    flipkart
# 50    flipkart
# 51    flipkart
# 52    flipkart
# 53    flipkart
# 54    flipkart
# 55    flipkart
# 56    flipkart
# 57    flipkart
# ...

# %%
# How to replace values
demo['country'] = demo['country'].replace('XX', 'IN')

# %%
demo['city'] = demo['city'].replace('XX', 'City Name is XX')

# %%
demo.head(60)
# Out:
#    campaign_name country             city  payout_in_user_currency  \
# 0       Flipkart      IN       Bantumilli                     19.8
# 1       Flipkart      IN       Gachibowli                     12.6
# 2       Flipkart      IN           Khurda                     13.5
# 3       Flipkart      IN        Ahmedabad                      3.6
# 4       Flipkart      IN        Hyderabad                      3.6
# 5       Flipkart      IN           Rajkot                      3.6
# 6       Flipkart      IN           Howrah                      3.6
# 7       Flipkart      IN        Hyderabad                      3.6
# 8       Flipkart      IN            Delhi                      4.5
# 9       Flipkart      IN            Delhi                      4.5
# 10      Flipkart      IN            Delhi                      4.5
# 11      Flipkart      IN        Hyderabad                      1.8
# 12      Flipkart      IN        Hyderabad                      1.8
# ...

# %%
# how to change row name 
demo[['country', 'city']] = demo[['country', 'city']].replace({'country': {'IN': 'IND'}, 'city': {'City Name is XX': 'Indian City'}})

# %%
demo.head()
# Out:
#   campaign_name country        city  payout_in_user_currency created_date  \
# 0      Flipkart     IND  Bantumilli                     19.8     1/1/2024
# 1      Flipkart     IND  Gachibowli                     12.6     1/1/2024
# 2      Flipkart     IND      Khurda                     13.5     1/1/2024
# 3      Flipkart     IND   Ahmedabad                      3.6     1/1/2024
# 4      Flipkart     IND   Hyderabad                      3.6     1/1/2024
#
#   campaign_currency
# 0               INR
# 1               INR
# 2               INR
# 3               INR
# 4               INR

# %%
demo.rename(columns = {'payout_in_user_currency' : 'commission', 'created_date' : 'Date', 'campaign_currency' : "currency"}, inplace = True)

# %%
demo.head()
# Out:
#   campaign_name country        city  commission      Date currency
# 0      Flipkart     IND  Bantumilli        19.8  1/1/2024      INR
# 1      Flipkart     IND  Gachibowli        12.6  1/1/2024      INR
# 2      Flipkart     IND      Khurda        13.5  1/1/2024      INR
# 3      Flipkart     IND   Ahmedabad         3.6  1/1/2024      INR
# 4      Flipkart     IND   Hyderabad         3.6  1/1/2024      INR

# %%
demo.isnull().sum()
# Out:
# campaign_name    0
# country          0
# city             0
# commission       0
# Date             0
# currency         0
# dtype: int64

# %%
demo.memory_usage().sum()
# Out:
# 141680

# %%
demo['Date'] = pd.to_datetime(demo['Date'], errors='coerce')

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2949 entries, 0 to 2948
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_name  2949 non-null   object
#  1   country        2949 non-null   object
#  2   city           2949 non-null   object
#  3   commission     2949 non-null   float64
#  4   Date           2949 non-null   datetime64[ns]
#  5   currency       2949 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 138.4+ KB

# %%
demo['Date'].head(60)
# Out:
# 0    2024-01-01
# 1    2024-01-01
# 2    2024-01-01
# 3    2024-01-01
# 4    2024-01-01
# 5    2024-01-01
# 6    2024-01-01
# 7    2024-01-01
# 8    2024-01-01
# 9    2024-01-01
# 10   2024-01-01
# 11   2024-01-01
# 12   2024-01-01
# 13   2024-01-01
# 14   2024-01-01
# 15   2024-01-01
# 16   2024-01-01
# 17   2024-01-01
# 18   2024-01-01
# 19   2024-01-01
# 20   2024-01-01
# 21   2024-01-01
# 22   2024-01-01
# 23   2024-01-01
# 24   2024-01-01
# 25   2024-01-01
# 26   2024-01-01
# 27   2024-01-01
# 28   2024-01-01
# 29   2024-01-01
# 30   2024-01-01
# 31   2024-01-01
# 32   2024-01-01
# 33   2024-01-01
# 34   2024-01-01
# 35   2024-01-01
# 36   2024-01-01
# 37   2024-01-01
# 38   2024-01-01
# 39   2024-01-01
# 40   2024-01-01
# 41   2024-01-01
# 42   2024-01-01
# 43   2024-01-01
# 44   2024-01-01
# 45   2024-01-01
# 46   2024-01-01
# 47   2024-01-01
# 48   2024-01-01
# 49   2024-01-01
# 50   2024-01-01
# 51   2024-01-01
# 52   2024-01-01
# 53   2024-01-01
# 54   2024-01-01
# ...

# %%
demo['Date'][60:120]
# Out:
# 60    2024-01-01
# 61    2024-01-01
# 62    2024-01-01
# 63    2024-01-01
# 64    2024-01-01
# 65    2024-01-01
# 66    2024-01-01
# 67    2024-01-01
# 68    2024-01-01
# 69    2024-01-02
# 70    2024-01-02
# 71    2024-01-02
# 72    2024-01-02
# 73    2024-01-02
# 74    2024-01-02
# 75    2024-01-02
# 76    2024-01-02
# 77    2024-01-02
# 78    2024-01-02
# 79    2024-01-02
# 80    2024-01-02
# 81    2024-01-02
# 82    2024-01-03
# 83    2024-01-03
# 84    2024-01-03
# 85    2024-01-03
# 86    2024-01-03
# 87    2024-01-03
# 88    2024-01-03
# 89    2024-01-03
# 90    2024-01-03
# 91    2024-01-03
# 92    2024-01-03
# 93    2024-01-03
# 94    2024-01-03
# 95    2024-01-03
# 96    2024-01-03
# 97    2024-01-03
# 98    2024-01-04
# 99    2024-01-04
# 100   2024-01-05
# 101   2024-01-05
# 102   2024-01-05
# 103   2024-01-05
# 104   2024-01-05
# 105   2024-01-05
# 106   2024-01-05
# 107   2024-01-05
# 108   2024-01-05
# 109   2024-01-05
# 110   2024-01-05
# 111   2024-01-05
# ...

# %%
demo['Date'][120:180]
# Out:
# 120   2024-01-05
# 121   2024-01-05
# 122   2024-01-05
# 123   2024-01-05
# 124   2024-01-05
# 125   2024-01-05
# 126   2024-01-05
# 127   2024-01-05
# 128   2024-01-05
# 129   2024-01-06
# 130   2024-01-06
# 131   2024-01-06
# 132   2024-01-06
# 133   2024-01-06
# 134   2024-01-06
# 135   2024-01-06
# 136   2024-01-06
# 137   2024-01-06
# 138   2024-01-06
# 139   2024-01-06
# 140   2024-01-06
# 141   2024-01-06
# 142   2024-01-06
# 143   2024-01-06
# 144   2024-01-06
# 145   2024-01-06
# 146   2024-01-06
# 147   2024-01-06
# 148   2024-01-06
# 149   2024-01-06
# 150   2024-01-06
# 151   2024-01-06
# 152   2024-01-06
# 153   2024-01-06
# 154   2024-01-06
# 155   2024-01-06
# 156   2024-01-06
# 157   2024-01-06
# 158   2024-01-06
# 159   2024-01-06
# 160   2024-01-06
# 161   2024-01-06
# 162   2024-01-06
# 163   2024-01-07
# 164   2024-01-07
# 165   2024-01-07
# 166   2024-01-07
# 167   2024-01-07
# 168   2024-01-07
# 169   2024-01-07
# 170   2024-01-07
# 171   2024-01-07
# ...

# %%
! pip install skim
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mk744\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mk744\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install skimpy
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mk744\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mk744\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.11.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for skimpy from https://files.pythonhosted.org/packages/5a/a5/71055a3e624f367ac8c024b8c898621d5890064cc335cdaaefb25dce39ac/skimpy-0.0.15-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\mk744\Downloads\Power BI project\Shoogloo XO CR Jan-24 to Apr-24.csv")

# %%
from skimpy import skim
skim(df)
# Out:
# c:\Users\mk744\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2949   │ │ float64     │ 64    │                                                          │
# ...

# %%
from skimpy import generate_test_data, skim
df = generate_test_data()
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 1000   │ │ float64     │ 3     │ │ class                 │                                │
# │ │ Number of columns │ 13     │ │ category    │ 2     │ │ location              │                                │
# │ └───────────────────┴────────┘ │ datetime64  │ 2     │ └───────────────────────┘                                │
# ...
