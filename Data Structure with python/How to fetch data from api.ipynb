# %%
import pandas as pd
import requests

# %%
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-05-01T02:30:17+05:30&end_date=2024-05-15T02:30:17+05:30&page=1&per_page=1000')

# %% [markdown]
# # Cuelinks API module

# %%
import requests

# Define your headers
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',
    # Add any other headers you need
}

# Make the GET request with headers
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-05-01T02:30:17+05:30&end_date=2024-05-15T02:30:17+05:30&page=1&per_page=1000', headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Process the response
    ans= response.json()['transactions']
else:
    # Handle the error
    print("Error:", response.status_code)

# %%
ans
# Out:
# [{'id': 16856254,
#   'aff_sub': 'W78KAdIb5EWsFYboITyg',
#   'referrer_url': 'https://hyyzo.com/',
#   'sale_amount': 1100.0,
#   'currency': 'INR',
#   'user_commission': 49.5,
#   'status': 'pending',
#   'store_name': 'Myntra',
#   'campaign_id': 101,
#   'transaction_date': '2024-05-02',
#   'extra_info': '1266538-9433970-7870603',
#   'pub_affiliate_id': None,
#   'subid1': 'W78KAdIb5EWsFYboITyg',
#   'subid2': '172',
#   'subid3': 'hyyzo',
#   'subid4': '',
#   'subid5': ''},
#  {'id': 16856279,
#   'aff_sub': 'tUJUcYfVr8MdrmNGNgCg',
#   'referrer_url': 'https://hyyzo.com/',
#   'sale_amount': 1726.0,
#   'currency': 'INR',
#   'user_commission': 77.67,
#   'status': 'pending',
#   'store_name': 'Myntra',
#   'campaign_id': 101,
#   'transaction_date': '2024-05-02',
#   'extra_info': '1266528-8207445-1537203',
#   'pub_affiliate_id': None,
#   'subid1': 'tUJUcYfVr8MdrmNGNgCg',
#   'subid2': '172',
#   'subid3': 'hyyzo',
#   'subid4': '',
#   'subid5': ''},
#  {'id': 16856309,
# ...

# %%
data = pd.DataFrame(ans)

# %%
data.head()
# Out:
#          id               aff_sub        referrer_url  sale_amount currency  \
# 0  16856254  W78KAdIb5EWsFYboITyg  https://hyyzo.com/       1100.0      INR
# 1  16856279  tUJUcYfVr8MdrmNGNgCg  https://hyyzo.com/       1726.0      INR
# 2  16856309  uVG8uoYD6HvahBg50MFl  https://hyyzo.com/       1100.0      INR
# 3  16856351  4ZxL1vaZe69rZHFBRWnj  https://hyyzo.com/       1100.0      INR
# 4  16856386  7FsRAUE8uqtCOJqAryFA  https://hyyzo.com/       1100.0      INR
#
#    user_commission   status store_name  campaign_id transaction_date  \
# 0            49.50  pending     Myntra          101       2024-05-02
# 1            77.67  pending     Myntra          101       2024-05-02
# 2            49.50  pending     Myntra          101       2024-05-02
# 3            49.50  pending     Myntra          101       2024-05-02
# 4            49.50  pending     Myntra          101       2024-05-02
#
#                 extra_info pub_affiliate_id                subid1 subid2  \
# ...

# %%
# import pymysql
# from sqlalchemy import create_engine
# import pandas as pd
# import warnings
# warnings.filterwarnings("ignore")
# engine = create_engine('mysql+pymysql://root:@localhost/Cuelinks_fs')
# data.to_sql('Api_data', con=engine, if_exists='append', index=False)

# %%
select_relevent_columns = data[['id','sale_amount',  'currency', 'user_commission', 'status', 'store_name', 'transaction_date']]

# %%
select_relevent_columns
# Out:
#           id  sale_amount currency  user_commission   status    store_name  \
# 0   16856254    1100.0000      INR            49.50  pending        Myntra
# 1   16856279    1726.0000      INR            77.67  pending        Myntra
# 2   16856309    1100.0000      INR            49.50  pending        Myntra
# 3   16856351    1100.0000      INR            49.50  pending        Myntra
# 4   16856386    1100.0000      INR            49.50  pending        Myntra
# 5   16856441    1100.0000      INR            49.50  pending        Myntra
# 6   16856447    1100.0000      INR            49.50  pending        Myntra
# 7   16856526    1100.0000      INR            49.50  pending        Myntra
# 8   16856537    1100.0000      INR            49.50  pending        Myntra
# 9   16856539    1100.0000      INR            49.50  pending        Myntra
# 10  16856546    2392.0000      INR           107.64  pending        Myntra
# ...

# %%
select_relevent_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                30 non-null     int64
#  1   sale_amount       30 non-null     float64
#  2   currency          30 non-null     object
#  3   user_commission   30 non-null     float64
#  4   status            30 non-null     object
#  5   store_name        30 non-null     object
#  6   transaction_date  30 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.8+ KB

# %%
select_relevent_columns.describe()
# Out:
#                  id  sale_amount  user_commission
# count  3.000000e+01    30.000000        30.000000
# mean   1.691383e+07  1556.603493        68.305333
# std    6.991528e+04  1211.873583        53.108713
# min    1.685625e+07    89.000000         4.010000
# 25%    1.685653e+07  1100.000000        49.500000
# 50%    1.688634e+07  1100.000000        49.500000
# 75%    1.695759e+07  1963.000000        83.617500
# max    1.707164e+07  4638.000100       208.710000

# %%
select_relevent_columns[['sale_amount',  'currency', 'user_commission', 'status', 'store_name', 'transaction_date']].value_counts()
# Out:
# sale_amount  currency  user_commission  status   store_name    transaction_date
# 1100.0000    INR       49.50            pending  Myntra        2024-05-02          13
# 89.0000      INR       4.01             pending  Myntra        2024-05-13           1
# 2042.0000    INR       91.89            pending  Myntra        2024-05-01           1
# 4528.0000    INR       203.76           pending  Myntra        2024-05-09           1
# 4427.0000    INR       199.22           pending  Myntra        2024-05-03           1
# 3064.0000    INR       85.60            pending  Croma Retail  2024-05-08           1
# 2526.0001    INR       113.67           pending  Myntra        2024-05-03           1
# 2392.0000    INR       107.64           pending  Myntra        2024-05-02           1
# 2307.0000    INR       103.82           pending  Myntra        2024-05-15           1
# 1726.0000    INR       77.67            pending  Myntra        2024-05-02           1
# ...

# %%
select_relevent_columns.value_counts()
# Out:
# id        sale_amount  currency  user_commission  status   store_name    transaction_date
# 16856254  1100.0000    INR       49.50            pending  Myntra        2024-05-02          1
# 16856279  1726.0000    INR       77.67            pending  Myntra        2024-05-02          1
# 17047981  89.0000      INR       4.01             pending  Myntra        2024-05-13          1
# 17029709  674.0000     INR       30.33            pending  Myntra        2024-05-12          1
# 17029636  608.0000     INR       27.36            pending  Myntra        2024-05-12          1
# 17016439  1199.0000    INR       53.96            pending  Myntra        2024-05-11          1
# 16980497  4528.0000    INR       203.76           pending  Myntra        2024-05-09          1
# 16975839  227.1046     INR       10.22            pending  Myntra        2024-05-08          1
# 16957708  4638.0001    INR       208.71           pending  Myntra        2024-05-07          1
# ...

# %%
ans = select_relevent_columns[select_relevent_columns['sale_amount'] == 1100.0000]
ans
# Out:
#           id  sale_amount currency  user_commission   status store_name  \
# 0   16856254       1100.0      INR             49.5  pending     Myntra
# 2   16856309       1100.0      INR             49.5  pending     Myntra
# 3   16856351       1100.0      INR             49.5  pending     Myntra
# 4   16856386       1100.0      INR             49.5  pending     Myntra
# 5   16856441       1100.0      INR             49.5  pending     Myntra
# 6   16856447       1100.0      INR             49.5  pending     Myntra
# 7   16856526       1100.0      INR             49.5  pending     Myntra
# 8   16856537       1100.0      INR             49.5  pending     Myntra
# 9   16856539       1100.0      INR             49.5  pending     Myntra
# 11  16856630       1100.0      INR             49.5  pending     Myntra
# 12  16856635       1100.0      INR             49.5  pending     Myntra
# 13  16856643       1100.0      INR             49.5  pending     Myntra
# ...

# %%
select_relevent_columns[select_relevent_columns['sale_amount'].isin([1100.0000])]
# Out:
#           id  sale_amount currency  user_commission   status store_name  \
# 0   16856254       1100.0      INR             49.5  pending     Myntra
# 2   16856309       1100.0      INR             49.5  pending     Myntra
# 3   16856351       1100.0      INR             49.5  pending     Myntra
# 4   16856386       1100.0      INR             49.5  pending     Myntra
# 5   16856441       1100.0      INR             49.5  pending     Myntra
# 6   16856447       1100.0      INR             49.5  pending     Myntra
# 7   16856526       1100.0      INR             49.5  pending     Myntra
# 8   16856537       1100.0      INR             49.5  pending     Myntra
# 9   16856539       1100.0      INR             49.5  pending     Myntra
# 11  16856630       1100.0      INR             49.5  pending     Myntra
# 12  16856635       1100.0      INR             49.5  pending     Myntra
# 13  16856643       1100.0      INR             49.5  pending     Myntra
# ...

# %% [markdown]
# # isin() very useful method to find specific rows

# %%
# select_relevent_columns[select_relevent_columns['payout'].isin([49.50,77.67])]

# %%
# select_relevent_columns[(select_relevent_columns['payout']== 49.50) | (select_relevent_columns['payout']==77.67)]

# %%
import warnings
warnings.filterwarnings('ignore')
new_columns = {'user_commission': 'payout',
               'store_name': 'Campaign_name',
               "transaction_date": 'Date'}
select_relevent_columns.rename(columns=new_columns, inplace=True)

# %%
select_relevent_columns
# Out:
#           id  sale_amount currency  payout   status Campaign_name        Date
# 0   16856254    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 1   16856279    1726.0000      INR   77.67  pending        Myntra  2024-05-02
# 2   16856309    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 3   16856351    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 4   16856386    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 5   16856441    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 6   16856447    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 7   16856526    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 8   16856537    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 9   16856539    1100.0000      INR   49.50  pending        Myntra  2024-05-02
# 10  16856546    2392.0000      INR  107.64  pending        Myntra  2024-05-02
# ...

# %%
select_relevent_columns['Date'] = pd.to_datetime(select_relevent_columns['Date'])

# %%
select_relevent_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             30 non-null     int64
#  1   sale_amount    30 non-null     float64
#  2   currency       30 non-null     object
#  3   payout         30 non-null     float64
#  4   status         30 non-null     object
#  5   Campaign_name  30 non-null     object
#  6   Date           30 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 1.8+ KB

# %%
import matplotlib.pyplot as plt

# Visualize the distributions of numerical features using histograms
select_relevent_columns.hist(figsize=(10, 8))
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()

# %%
import seaborn as sns

# Visualize the distributions of numerical features using box plots
plt.figure(figsize=(10, 8))
sns.boxplot(data=select_relevent_columns[['sale_amount', 'payout']])
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot trends in Clicks, Payout, and Sales Amount over time using line plots
plt.figure(figsize=(10, 6))
plt.plot(select_relevent_columns['Date'], select_relevent_columns['payout'], label='payout')
plt.plot(select_relevent_columns['Date'], select_relevent_columns['sale_amount'], label='sale_amount')
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Trends Over Time')
plt.legend()
plt.show()

# %%
import seaborn as sns

# Create visualizations to compare Clicks, Payout, and Sales Amount across different partners
plt.figure(figsize=(10, 6))
sns.barplot(data=select_relevent_columns, x='Date', y='sale_amount', estimator=sum, ci=None)
plt.title('Total sale amount Across time')
plt.xlabel('time')
plt.ylabel('Total sale amount')
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns

# Create visualizations to compare Clicks, Payout, and Sales Amount across different partners
plt.figure(figsize=(10, 6))
sns.barplot(data=select_relevent_columns, x='Date', y='payout', estimator=sum, ci=None)
plt.title('Total payout Across time')
plt.xlabel('time')
plt.ylabel('Total payout')
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame containing the dataset
sns.histplot(data['user_commission'], kde=True, color='skyblue')
plt.title('Normal Distribution Plot for Column "id"')
plt.xlabel('ID')
plt.ylabel('Density')
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Compute the correlation matrix between numerical features
# correlation_matrix = select_relevent_columns.corr()

# # Visualize correlations using a heatmap
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
# plt.title('Correlation Matrix of Numerical Features')
# # plt.show()

# %%
from scipy.stats import ttest_ind

# Assuming df_campaign1 and df_campaign2 are DataFrames containing data for two different marketing campaigns
clicks_campaign1 = select_relevent_columns['sale_amount']
clicks_campaign2 = select_relevent_columns['payout']

# Perform t-test
t_statistic, p_value = ttest_ind(clicks_campaign1, clicks_campaign2)

# Check if the p-value is less than the significance level (e.g., 0.05) to determine statistical significance
if p_value < 0.05:
    print("The observed difference in clicks between the two campaigns is statistically significant.")
else:
    print("There is no statistically significant difference in clicks between the two campaigns.")
# Out:
# The observed difference in clicks between the two campaigns is statistically significant.

# %%
import requests

# Define your headers
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',
    # Add any other headers you need
}

# Make the GET request with headers
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-01-01T02:30:17+05:30&end_date=2024-01-31T02:30:17+05:30&page=1&per_page=1000', headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Process the response
    ans= response.json()['transactions']
else:
    # Handle the error
    print("Error:", response.status_code)

# %%
import pandas as pd
df = pd.DataFrame(ans)

# %%
ans
# Out:
# [{'id': 15013982,
#   'aff_sub': 'CCk7o6pj0j1pkWkU0Kwe',
#   'referrer_url': 'https://hyyzo.com/',
#   'sale_amount': 3864.0,
#   'currency': 'INR',
#   'user_commission': 220.25,
#   'status': 'payable',
#   'store_name': 'Ajio',
#   'campaign_id': 2589,
#   'transaction_date': '2024-01-01',
#   'extra_info': 'FN2959409643',
#   'pub_affiliate_id': None,
#   'subid1': 'CCk7o6pj0j1pkWkU0Kwe',
#   'subid2': '195',
#   'subid3': 'hyyzo',
#   'subid4': '',
#   'subid5': ''},
#  {'id': 15018691,
#   'aff_sub': '',
#   'referrer_url': 'https://flipshope.com/',
#   'sale_amount': 1041.0,
#   'currency': 'INR',
#   'user_commission': 59.34,
#   'status': 'rejected',
#   'store_name': 'Ajio',
#   'campaign_id': 2589,
#   'transaction_date': '2024-01-02',
#   'extra_info': 'FN4379402289',
#   'pub_affiliate_id': None,
#   'subid1': '',
#   'subid2': '1704080522923',
#   'subid3': '',
#   'subid4': '',
#   'subid5': ''},
#  {'id': 15019871,
#   'aff_sub': 's53rVoPx0G4VakzWp9NA',
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.head()
# Out:
#          id               aff_sub            referrer_url  sale_amount  \
# 0  15013982  CCk7o6pj0j1pkWkU0Kwe      https://hyyzo.com/       3864.0
# 1  15018691                        https://flipshope.com/       1041.0
# 2  15019871  s53rVoPx0G4VakzWp9NA      https://hyyzo.com/       1958.0
# 3  15020512  RGiWGpoZ4CTP2w9zul5T      https://hyyzo.com/       3324.0
# 4  15020603  0SuoZFJyeodeqOSUUM0F      https://hyyzo.com/       3904.0
#
#   currency  user_commission    status store_name  campaign_id  \
# 0      INR           220.25   payable       Ajio         2589
# 1      INR            59.34  rejected       Ajio         2589
# 2      INR           111.61  rejected       Ajio         2589
# 3      INR           189.47   payable       Ajio         2589
# 4      INR           222.53   payable       Ajio         2589
#
#   transaction_date    extra_info pub_affiliate_id                subid1  \
# 0       2024-01-01  FN2959409643             None  CCk7o6pj0j1pkWkU0Kwe
# ...

# %%
df.columns
# Out:
# Index(['id', 'aff_sub', 'referrer_url', 'sale_amount', 'currency',
#        'user_commission', 'status', 'store_name', 'campaign_id',
#        'transaction_date', 'extra_info', 'pub_affiliate_id', 'subid1',
#        'subid2', 'subid3', 'subid4', 'subid5'],
#       dtype='object')

# %%
select_cols = df[['subid3','store_name', 'id','status','transaction_date','sale_amount','user_commission','currency','subid1']]

# %%
select_cols.head()
# Out:
#   subid3 store_name        id    status transaction_date  sale_amount  \
# 0  hyyzo       Ajio  15013982   payable       2024-01-01       3864.0
# 1              Ajio  15018691  rejected       2024-01-02       1041.0
# 2  hyyzo       Ajio  15019871  rejected       2024-01-02       1958.0
# 3  hyyzo       Ajio  15020512   payable       2024-01-02       3324.0
# 4  hyyzo       Ajio  15020603   payable       2024-01-02       3904.0
#
#    user_commission currency                subid1
# 0           220.25      INR  CCk7o6pj0j1pkWkU0Kwe
# 1            59.34      INR
# 2           111.61      INR  s53rVoPx0G4VakzWp9NA
# 3           189.47      INR  RGiWGpoZ4CTP2w9zul5T
# 4           222.53      INR  0SuoZFJyeodeqOSUUM0F

# %%
Rename_cols = select_cols.rename(columns = {'subid3':'Inventory', 'store_name':'Campaign_Name', 'id':'Id',
                                            'status':'Status', 'transaction_date':'Date', 'sale_amount':'Amount', 'user_commission':'Payout',
                                            'currency':'Currency', 'subid1':'Sub_Id'})

# %%
Rename_cols.head()
# Out:
#   Inventory Campaign_Name        Id    Status        Date  Amount  Payout  \
# 0     hyyzo          Ajio  15013982   payable  2024-01-01  3864.0  220.25
# 1                    Ajio  15018691  rejected  2024-01-02  1041.0   59.34
# 2     hyyzo          Ajio  15019871  rejected  2024-01-02  1958.0  111.61
# 3     hyyzo          Ajio  15020512   payable  2024-01-02  3324.0  189.47
# 4     hyyzo          Ajio  15020603   payable  2024-01-02  3904.0  222.53
#
#   Currency                Sub_Id
# 0      INR  CCk7o6pj0j1pkWkU0Kwe
# 1      INR
# 2      INR  s53rVoPx0G4VakzWp9NA
# 3      INR  RGiWGpoZ4CTP2w9zul5T
# 4      INR  0SuoZFJyeodeqOSUUM0F

# %%
import requests

# Define your headers
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',
    # Add any other headers you need
}

# Make the GET request with headers
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-01-31T02:30:17+05:30&end_date=2024-02-29T02:30:17+05:30&page=1&per_page=1000', headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Process the response
    ans_1= response.json()['transactions']
else:
    # Handle the error
    print("Error:", response.status_code)

# %%
df_1 = pd.DataFrame(ans_1)

# %%
df_1.shape
# Out:
# (30, 17)

# %%
df_1.columns
# Out:
# Index(['id', 'aff_sub', 'referrer_url', 'sale_amount', 'currency',
#        'user_commission', 'status', 'store_name', 'campaign_id',
#        'transaction_date', 'extra_info', 'pub_affiliate_id', 'subid1',
#        'subid2', 'subid3', 'subid4', 'subid5'],
#       dtype='object')

# %%
Select_Relevent_cols = df_1[['subid3','store_name', 'id','status','transaction_date','sale_amount','user_commission','currency','subid1']]

# %%
Select_Relevent_cols.head()
# Out:
#   subid3 store_name        id    status transaction_date  sale_amount  \
# 0  hyyzo       Ajio  15382398  rejected       2024-01-31       1820.0
# 1  hyyzo       Ajio  15382408   payable       2024-01-31       1764.0
# 2  hyyzo       Ajio  15383055  rejected       2024-01-31       1827.0
# 3  hyyzo       Ajio  15383114  rejected       2024-01-31       1827.0
# 4  hyyzo       Ajio  15383126  rejected       2024-01-31       1827.0
#
#    user_commission currency                subid1
# 0           207.48      INR  5LaTQHpg3Uq2ZAl5QL7a
# 1           201.10      INR  EHplvZ70qsSnlYmcg5JE
# 2           208.28      INR  y5xHtuUbYyy2raul9eoj
# 3           208.28      INR  Tj2EhORIkoPu6pptRRET
# 4           208.28      INR  YcPXJTwnDWfy6rVUeVRS

# %%
Rename_cols_1 = Select_Relevent_cols.rename(columns = {'subid3':'Inventory', 'store_name':'Campaign_Name', 'id':'Id',
                                            'status':'Status', 'transaction_date':'Date', 'sale_amount':'Amount', 'user_commission':'Payout',
                                            'currency':'Currency', 'subid1':'Sub_Id'})

# %%
Rename_cols_1.head()
# Out:
#   Inventory Campaign_Name        Id    Status        Date  Amount  Payout  \
# 0     hyyzo          Ajio  15382398  rejected  2024-01-31  1820.0  207.48
# 1     hyyzo          Ajio  15382408   payable  2024-01-31  1764.0  201.10
# 2     hyyzo          Ajio  15383055  rejected  2024-01-31  1827.0  208.28
# 3     hyyzo          Ajio  15383114  rejected  2024-01-31  1827.0  208.28
# 4     hyyzo          Ajio  15383126  rejected  2024-01-31  1827.0  208.28
#
#   Currency                Sub_Id
# 0      INR  5LaTQHpg3Uq2ZAl5QL7a
# 1      INR  EHplvZ70qsSnlYmcg5JE
# 2      INR  y5xHtuUbYyy2raul9eoj
# 3      INR  Tj2EhORIkoPu6pptRRET
# 4      INR  YcPXJTwnDWfy6rVUeVRS

# %%
Append_sheet = pd.concat([Rename_cols, Rename_cols_1], ignore_index=True)

# %%
Append_sheet.shape
# Out:
# (60, 9)

# %%
import requests
headers
{
     'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',  
}
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-03-01T02:30:17+05:30&end_date=2024-03-30T02:30:17+05:30&page=1&per_page=1000', headers=headers)
if response.status_code == 200:
     df = response.json()['transactions']
else:
     print('Error', response.status.code)

# %%
df_2 = pd.DataFrame(df)

# %%
df_2.head()
# Out:
#          id               aff_sub        referrer_url  sale_amount currency  \
# 0  15798588  Zh6ZmfIM8vXcSgIdnpb7  https://hyyzo.com/       754.32      INR
# 1  15798589  Zh6ZmfIM8vXcSgIdnpb7  https://hyyzo.com/       519.00      INR
# 2  15798590  Zh6ZmfIM8vXcSgIdnpb7  https://hyyzo.com/       754.32      INR
# 3  15798591  Zh6ZmfIM8vXcSgIdnpb7  https://hyyzo.com/      1677.20      INR
# 4  15801020  ORkrdsQvKOMGCz8Iou0w  https://hyyzo.com/       449.46      INR
#
#    user_commission   status store_name  campaign_id transaction_date  \
# 0           107.49  pending       Ajio         2589       2024-03-01
# 1            73.96  pending       Ajio         2589       2024-03-01
# 2           107.49  pending       Ajio         2589       2024-03-01
# 3           239.00  pending       Ajio         2589       2024-03-01
# 4            64.05  pending       Ajio         2589       2024-03-01
#
#                   extra_info pub_affiliate_id                subid1 subid2  \
# ...

# %%
Select_Relevent_cols_1 = df_2[['subid3','store_name', 'id','status','transaction_date','sale_amount','user_commission','currency','subid1']]

# %%
Rename_cols_2 = Select_Relevent_cols_1.rename(columns = {'subid3':'Inventory', 'store_name':'Campaign_Name', 'id':'Id',
                                            'status':'Status', 'transaction_date':'Date', 'sale_amount':'Amount', 'user_commission':'Payout',
                                            'currency':'Currency', 'subid1':'Sub_Id'})

# %%
Rename_cols_2
# Out:
#    Inventory Campaign_Name        Id   Status        Date   Amount  Payout  \
# 0      hyyzo          Ajio  15798588  pending  2024-03-01   754.32  107.49
# 1      hyyzo          Ajio  15798589  pending  2024-03-01   519.00   73.96
# 2      hyyzo          Ajio  15798590  pending  2024-03-01   754.32  107.49
# 3      hyyzo          Ajio  15798591  pending  2024-03-01  1677.20  239.00
# 4      hyyzo          Ajio  15801020  pending  2024-03-01   449.46   64.05
# 5      hyyzo          Ajio  15801021  pending  2024-03-01   389.54   55.51
# 6      hyyzo          Ajio  15805275  pending  2024-03-01  2012.16  286.73
# 7      hyyzo          Ajio  15805276  pending  2024-03-01  2013.78  286.96
# 8      hyyzo          Ajio  15805498  pending  2024-03-01   175.00   24.94
# 9      hyyzo          Ajio  15805499  pending  2024-03-01   416.00   59.28
# 10     hyyzo          Ajio  15805500  pending  2024-03-01   364.00   51.87
# ...

# %%
Append_sheet_1 = pd.concat([Append_sheet, Rename_cols_2], ignore_index=True)

# %%
Append_sheet_1
# Out:
#    Inventory Campaign_Name        Id    Status        Date  Amount  Payout  \
# 0      hyyzo          Ajio  15013982   payable  2024-01-01  3864.0  220.25
# 1                     Ajio  15018691  rejected  2024-01-02  1041.0   59.34
# 2      hyyzo          Ajio  15019871  rejected  2024-01-02  1958.0  111.61
# 3      hyyzo          Ajio  15020512   payable  2024-01-02  3324.0  189.47
# 4      hyyzo          Ajio  15020603   payable  2024-01-02  3904.0  222.53
# ..       ...           ...       ...       ...         ...     ...     ...
# 85     hyyzo          Ajio  15805523   pending  2024-03-01   419.7   59.81
# 86     hyyzo          Ajio  15805524   pending  2024-03-01   389.7   55.53
# 87     hyyzo          Ajio  15805525   pending  2024-03-01   419.7   59.81
# 88     hyyzo          Ajio  15805526   pending  2024-03-01   420.0   59.85
# 89     hyyzo          Ajio  15805527   pending  2024-03-01   449.7   64.08
#
#    Currency                Sub_Id
# ...

# %%
import requests
headers
{
     'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',  
}
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-03-31T02:30:17+05:30&end_date=2024-04-29T02:30:17+05:30&page=1&per_page=1000', headers=headers)
if response.status_code == 200:
     df_3 = response.json()['transactions']
else:
     print('Error', response.status.code)

# %%
df_4 = pd.DataFrame(df_3)

# %%
df_4.head()
# Out:
#          id               aff_sub        referrer_url  sale_amount currency  \
# 0  16404592  HbBcczO0CT4j2O366qkL  https://hyyzo.com/       3807.0      INR
# 1  16404842  vylcdSYOggFD4DH8qN15  https://hyyzo.com/       3807.0      INR
# 2  16404896  uNSghMepqDGO6JBBkblV  https://hyyzo.com/       3849.0      INR
# 3  16404921  HbBcczO0CT4j2O366qkL  https://hyyzo.com/       3807.0      INR
# 4  16404960  6ofUTGmgYxneTTASqU5e  https://hyyzo.com/       1099.0      INR
#
#    user_commission   status store_name  campaign_id transaction_date  \
# 0           171.32  pending     Myntra          101       2024-04-03
# 1           171.32  pending     Myntra          101       2024-04-03
# 2           173.21  pending     Myntra          101       2024-04-03
# 3           171.32  pending     Myntra          101       2024-04-03
# 4            49.46  pending     Myntra          101       2024-04-03
#
#                 extra_info pub_affiliate_id                subid1 subid2  \
# ...

# %%
Select_Relevent_cols_2 = df_4[['subid3','store_name', 'id','status','transaction_date','sale_amount','user_commission','currency','subid1']]

# %%
Rename_cols_3 = Select_Relevent_cols_2.rename(columns = {'subid3':'Inventory', 'store_name':'Campaign_Name', 'id':'Id',
                                            'status':'Status', 'transaction_date':'Date', 'sale_amount':'Amount', 'user_commission':'Payout',
                                            'currency':'Currency', 'subid1':'Sub_Id'})

# %%
Append_sheet_2 = pd.concat([Append_sheet_1, Rename_cols_3], ignore_index=True)

# %%
Append_sheet_2
# Out:
#     Inventory Campaign_Name        Id    Status        Date   Amount  Payout  \
# 0       hyyzo          Ajio  15013982   payable  2024-01-01  3864.00  220.25
# 1                      Ajio  15018691  rejected  2024-01-02  1041.00   59.34
# 2       hyyzo          Ajio  15019871  rejected  2024-01-02  1958.00  111.61
# 3       hyyzo          Ajio  15020512   payable  2024-01-02  3324.00  189.47
# 4       hyyzo          Ajio  15020603   payable  2024-01-02  3904.00  222.53
# ..        ...           ...       ...       ...         ...      ...     ...
# 115     hyyzo          Ajio  16553044   pending  2024-04-14   366.36   52.21
# 116     hyyzo          Ajio  16553045   pending  2024-04-14   619.56   88.29
# 117     hyyzo          Ajio  16553333   pending  2024-04-14   449.70   64.08
# 118     hyyzo          Ajio  16553334   pending  2024-04-14   449.70   64.08
# 119     hyyzo          Ajio  16553335   pending  2024-04-14   510.00   72.68
#
#     Currency                Sub_Id
# ...

# %%
import requests
headers
{
     'Content-Type': 'application/json',
    'Authorization': 'Token token=PJ35bUv8Lo0EAZfIg-1uwLSBmdUiaDLD_vcL0qJvmx8',  
}
response = requests.get('https://www.cuelinks.com/api/v2/transactions.json?start_date=2024-04-30T02:30:17+05:30&end_date=2024-05-27T02:30:17+05:30&page=1&per_page=1000', headers=headers)
if response.status_code == 200:
     df_5 = response.json()['transactions']
else:
     print('Error', response.status.code)

# %%
df_6 = pd.DataFrame(df_5)

# %%
df_6.shape
# Out:
# (30, 17)

# %%
Select_Relevent_cols_3 = df_6[['subid3','store_name', 'id','status','transaction_date','sale_amount','user_commission','currency','subid1']]

# %%
Rename_cols_4 = Select_Relevent_cols_3.rename(columns = {'subid3':'Inventory', 'store_name':'Campaign_Name', 'id':'Id',
                                            'status':'Status', 'transaction_date':'Date', 'sale_amount':'Amount', 'user_commission':'Payout',
                                            'currency':'Currency', 'subid1':'Sub_Id'})

# %%
Rename_cols_4
# Out:
#    Inventory Campaign_Name        Id   Status        Date       Amount  \
# 0                   Myntra  16814476  pending  2024-04-30  1247.999900
# 1      hyyzo        Myntra  16814477  pending  2024-04-30   298.000000
# 2      hyyzo        Myntra  16814481  pending  2024-04-30  5216.000000
# 3      hyyzo           1mg  16816135  pending  2024-04-30   588.142857
# 4      hyyzo        Myntra  16856254  pending  2024-05-02  1100.000000
# 5      hyyzo        Myntra  16856279  pending  2024-05-02  1726.000000
# 6      hyyzo        Myntra  16856309  pending  2024-05-02  1100.000000
# 7      hyyzo        Myntra  16856351  pending  2024-05-02  1100.000000
# 8      hyyzo        Myntra  16856386  pending  2024-05-02  1100.000000
# 9      hyyzo        Myntra  16856441  pending  2024-05-02  1100.000000
# 10     hyyzo        Myntra  16856447  pending  2024-05-02  1100.000000
# 11     hyyzo        Myntra  16856526  pending  2024-05-02  1100.000000
# ...

# %%
Append_sheet_3 = pd.concat([Append_sheet_2, Rename_cols_4], ignore_index=True)

# %%
Append_sheet_3.isnull().sum()
# Out:
# Inventory        0
# Campaign_Name    0
# Id               0
# Status           0
# Date             0
# Amount           0
# Payout           0
# Currency         0
# Sub_Id           0
# dtype: int64

# %%
Append_sheet_3.to_csv('Cuelinks_Hyzzo.csv', index=False)

# %%
Adm = pd.read_csv(r'C:\Users\mk744\OneDrive - Poornima University\Desktop\Admitad Data\Admitad_XO.csv')

# %%
Adm.head()
# Out:
#   Inventory      Campaign_Name          Id   Status        Date   Amount  \
# 0     Hyyzo  TataCliq [CPS] IN  1055337333  pending  2024-05-26   2688.0
# 1     Hyyzo  Flipkart [CPS] IN  1055251343  pending  2024-05-26  12499.0
# 2     Hyyzo  Flipkart [CPS] IN  1055206793  pending  2024-05-25    188.0
# 3     Hyyzo  Flipkart [CPS] IN  1055138754  pending  2024-05-25      1.0
# 4     Hyyzo  Flipkart [CPS] IN  1055138735  pending  2024-05-25      1.0
#
#    Payout Currency                Sub_Id
# 0   94.08      INR  PmZfYcTDDl3uqQyiHLBk
# 1    0.00      INR  vLVwF1M3NLn47I9Cb1Bt
# 2    4.20      INR  7a8vBv5IfS1aYVSx5yy3
# 3    0.00      INR  6ZD3cAlicyn2BONpRLNA
# 4    0.00      INR  6ZD3cAlicyn2BONpRLNA

# %%
Adm['Partner'] = 'Admitad'

# %%
Adm
# Out:
#               Inventory      Campaign_Name          Id    Status        Date  \
# 0                 Hyyzo  TataCliq [CPS] IN  1055337333   pending  2024-05-26
# 1                 Hyyzo  Flipkart [CPS] IN  1055251343   pending  2024-05-26
# 2                 Hyyzo  Flipkart [CPS] IN  1055206793   pending  2024-05-25
# 3                 Hyyzo  Flipkart [CPS] IN  1055138754   pending  2024-05-25
# 4                 Hyyzo  Flipkart [CPS] IN  1055138735   pending  2024-05-25
# ...                 ...                ...         ...       ...         ...
# 3742  Real Pricetracker           Udemy WW  1018417173  approved  2024-01-01
# 3743  Real Pricetracker           Udemy WW  1018417167  approved  2024-01-01
# 3744  Real Pricetracker           Udemy WW  1018417158  approved  2024-01-01
# 3745  Real Pricetracker           Udemy WW  1018417214  approved  2024-01-01
# 3746  Real Pricetracker           Udemy WW  1018417208  declined  2024-01-01
#
# ...

# %%
Append_sheet_3.head()
# Out:
#   Inventory Campaign_Name        Id    Status        Date  Amount  Payout  \
# 0     hyyzo          Ajio  15013982   payable  2024-01-01  3864.0  220.25
# 1                    Ajio  15018691  rejected  2024-01-02  1041.0   59.34
# 2     hyyzo          Ajio  15019871  rejected  2024-01-02  1958.0  111.61
# 3     hyyzo          Ajio  15020512   payable  2024-01-02  3324.0  189.47
# 4     hyyzo          Ajio  15020603   payable  2024-01-02  3904.0  222.53
#
#   Currency                Sub_Id
# 0      INR  CCk7o6pj0j1pkWkU0Kwe
# 1      INR
# 2      INR  s53rVoPx0G4VakzWp9NA
# 3      INR  RGiWGpoZ4CTP2w9zul5T
# 4      INR  0SuoZFJyeodeqOSUUM0F

# %%
Append_sheet_3['Partner'] = 'Cuelinks'

# %%
Append_sheet_3
# Out:
#     Inventory Campaign_Name        Id    Status        Date     Amount  \
# 0       hyyzo          Ajio  15013982   payable  2024-01-01  3864.0000
# 1                      Ajio  15018691  rejected  2024-01-02  1041.0000
# 2       hyyzo          Ajio  15019871  rejected  2024-01-02  1958.0000
# 3       hyyzo          Ajio  15020512   payable  2024-01-02  3324.0000
# 4       hyyzo          Ajio  15020603   payable  2024-01-02  3904.0000
# ..        ...           ...       ...       ...         ...        ...
# 145     hyyzo  Croma Retail  16957253   pending  2024-05-08  3064.0000
# 146     hyyzo        Myntra  16957708   pending  2024-05-07  4638.0001
# 147     hyyzo        Myntra  16975839   pending  2024-05-08   227.1046
# 148     hyyzo        Myntra  16980497   pending  2024-05-09  4528.0000
# 149     hyyzo        Myntra  17016439   pending  2024-05-11  1199.0000
#
#      Payout Currency                Sub_Id   Partner
# 0    220.25      INR  CCk7o6pj0j1pkWkU0Kwe  Cuelinks
# ...

# %%
Consolidated_Data = pd.concat([Adm, Append_sheet_3], ignore_index= True)

# %%
Consolidated_Data.isnull().sum()
# Out:
# Inventory           0
# Campaign_Name       0
# Id                  0
# Status              0
# Date                0
# Amount              0
# Payout              0
# Currency            0
# Sub_Id           1362
# Partner             0
# dtype: int64

# %%
Consolidated_Data.to_csv('Admitad_Cuelinks.csv', index = False)
